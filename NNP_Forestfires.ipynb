# %% [markdown]
# <a href="https://colab.research.google.com/github/chirag3096/ExcelR-Assignment/blob/main/NNP_Forestfires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
import seaborn as sns
from sklearn.feature_selection import SelectKBest
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_regression
from sklearn.preprocessing import StandardScaler
from keras.layers import Dense, Activation,Layer,Lambda

# %%
data=pd.read_csv('/content/gas_turbines.csv')

# %%
data.head()
# Out:
#        AT      AP      AH    AFDP  ...     TEY     CDP      CO     NOX
# 0  6.8594  1007.9  96.799  3.5000  ...  114.70  10.605  3.1547  82.722
# 1  6.7850  1008.4  97.118  3.4998  ...  114.72  10.598  3.2363  82.776
# 2  6.8977  1008.8  95.939  3.4824  ...  114.71  10.601  3.2012  82.468
# 3  7.0569  1009.2  95.249  3.4805  ...  114.72  10.606  3.1923  82.670
# 4  7.3978  1009.7  95.150  3.4976  ...  114.72  10.612  3.2484  82.311
#
# [5 rows x 11 columns]

# %%
Target = data['TEY']
data.drop(labels=['TEY'], axis=1,inplace = True)
data.insert(0, 'Y', Target)
data = data.rename({'Y':'TEY'}, axis = 1)

# %%
data.head()
# Out:
#       TEY      AT      AP      AH  ...     TAT     CDP      CO     NOX
# 0  114.70  6.8594  1007.9  96.799  ...  550.00  10.605  3.1547  82.722
# 1  114.72  6.7850  1008.4  97.118  ...  550.00  10.598  3.2363  82.776
# 2  114.71  6.8977  1008.8  95.939  ...  549.87  10.601  3.2012  82.468
# 3  114.72  7.0569  1009.2  95.249  ...  549.99  10.606  3.1923  82.670
# 4  114.72  7.3978  1009.7  95.150  ...  549.98  10.612  3.2484  82.311
#
# [5 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEY     15039 non-null  float64
#  1   AT      15039 non-null  float64
#  2   AP      15039 non-null  float64
#  3   AH      15039 non-null  float64
#  4   AFDP    15039 non-null  float64
#  5   GTEP    15039 non-null  float64
#  6   TIT     15039 non-null  float64
#  7   TAT     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#                 TEY            AT  ...            CO           NOX
# count  15039.000000  15039.000000  ...  15039.000000  15039.000000
# mean     134.188464     17.764381  ...      1.972499     68.190934
# std       15.829717      7.574323  ...      2.222206     10.470586
# min      100.170000      0.522300  ...      0.000388     27.765000
# 25%      127.985000     11.408000  ...      0.858055     61.303500
# 50%      133.780000     18.186000  ...      1.390200     66.601000
# 75%      140.895000     23.862500  ...      2.160400     73.935500
# max      174.610000     34.929000  ...     44.103000    119.890000
#
# [8 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# TEY     0
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
data.corr()
# Out:
#            TEY        AT        AP  ...       CDP        CO       NOX
# TEY   1.000000 -0.207495  0.146939  ...  0.988473 -0.541751 -0.102631
# AT   -0.207495  1.000000 -0.412953  ... -0.100705 -0.088588 -0.600006
# AP    0.146939 -0.412953  1.000000  ...  0.131198  0.041614  0.256744
# AH   -0.110272 -0.549432  0.042573  ... -0.182010  0.165505  0.143061
# AFDP  0.717995 -0.099333  0.040318  ...  0.727152 -0.334207 -0.037299
# GTEP  0.977042 -0.049103  0.078575  ...  0.993784 -0.508259 -0.208496
# TIT   0.891587  0.093067  0.029650  ...  0.887238 -0.688272 -0.231636
# TAT  -0.720356  0.338569 -0.223479  ... -0.744740  0.063404  0.009888
# CDP   0.988473 -0.100705  0.131198  ...  1.000000 -0.520783 -0.169103
# CO   -0.541751 -0.088588  0.041614  ... -0.520783  1.000000  0.316743
# NOX  -0.102631 -0.600006  0.256744  ... -0.169103  0.316743  1.000000
#
# [11 rows x 11 columns]

# %%
corr = data.corr()
fig, ax = plt.subplots(figsize=(15, 8))
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt=".2f")
plt.xticks(range(len(corr.columns)), corr.columns);
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
X = data.iloc[:,1:]
y = data.iloc[:,0]

# %%
def select_features(X_train, y_train, X_test):
    fs = SelectKBest(score_func=mutual_info_regression, k='all')
    fs.fit(X_train, y_train)
    X_train_fs = fs.transform(X_train)
    X_test_fs = fs.transform(X_test)
    return X_train_fs, X_test_fs, fs

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# %%
for i in range(len(fs.scores_)):
    print('Feature %d: %f' % (i, fs.scores_[i]))
fig, ax = plt.subplots(figsize=(10, 6))
plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
plt.show()
# Out:
# Feature 0: 0.403331
# Feature 1: 0.146443
# Feature 2: 0.090978
# Feature 3: 0.657095
# Feature 4: 1.590728
# Feature 5: 1.304544
# Feature 6: 0.911180
# Feature 7: 1.710731
# Feature 8: 0.506675
# Feature 9: 0.303267

# %%
X = data.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)
y = data.iloc[:,0]
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]
scaled_features=scaler.transform(X)

# %%
data_head=pd.DataFrame(scaled_features,columns=X.columns)
data_head
# Out:
#            AFDP      GTEP       TIT       TAT       CDP
# 0     -0.921232 -1.379101 -1.488376  0.585240 -1.357331
# 1     -0.921495 -1.363528 -1.482325  0.585240 -1.363676
# 2     -0.944385 -1.351309 -1.476275  0.568715 -1.360957
# 3     -0.946884 -1.348194 -1.464173  0.583969 -1.356424
# 4     -0.924389 -1.354663 -1.458123  0.582698 -1.350985
# ...         ...       ...       ...       ...       ...
# 15034 -0.865850 -1.498657 -2.063184  0.103453 -1.543161
# 15035 -0.913470 -1.438759 -2.268905 -0.276638 -1.513247
# 15036 -0.951488 -1.410967 -2.789257 -1.026650 -1.467922
# 15037 -0.988848 -1.447624 -2.456474 -0.528337 -1.422598
# 15038 -1.016605 -1.464635 -2.051083  0.057689 -1.377273
#
# [15039 rows x 5 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print('Shape of x_train: ', x_train.shape)
print('Shape of x_test: ', x_test.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Shape of x_train:  (10527, 5)
# Shape of x_test:  (4512, 5)
# Shape of y_train:  (10527,)
# Shape of y_test:  (4512,)

# %%
model = Sequential()
model.add(Dense(10, input_dim=5, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(6, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(1, kernel_initializer='he_uniform', activation='linear'))

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
model.fit(x_train,y_train, epochs=150, batch_size=40)
# Out:
# Epoch 1/150
# 264/264 [==============================] - 1s 2ms/step - loss: 0.6119 - mse: 0.6119
# Epoch 2/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3860 - mse: 0.3860
# Epoch 3/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3715 - mse: 0.3715
# Epoch 4/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 5/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3708 - mse: 0.3708
# Epoch 6/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 7/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3714 - mse: 0.3714
# Epoch 8/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3714 - mse: 0.3714
# Epoch 9/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3697 - mse: 0.3697
# Epoch 10/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3719 - mse: 0.3719
# Epoch 11/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3711 - mse: 0.3711
# Epoch 12/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 13/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3711 - mse: 0.3711
# Epoch 14/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3703 - mse: 0.3703
# Epoch 15/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 16/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3764 - mse: 0.3764
# Epoch 17/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 18/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3704 - mse: 0.3704
# Epoch 19/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3690 - mse: 0.3690
# Epoch 20/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3706 - mse: 0.3706
# Epoch 21/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3738 - mse: 0.3738
# Epoch 22/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3706 - mse: 0.3706
# Epoch 23/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3712 - mse: 0.3712
# Epoch 24/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3698 - mse: 0.3698
# Epoch 25/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3693 - mse: 0.3693
# Epoch 26/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3703 - mse: 0.3703
# Epoch 27/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3749 - mse: 0.3749
# Epoch 28/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3718 - mse: 0.3718
# Epoch 29/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3713 - mse: 0.3713
# Epoch 30/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3718 - mse: 0.3718
# Epoch 31/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 32/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3699 - mse: 0.3699
# Epoch 33/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3722 - mse: 0.3722
# Epoch 34/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3713 - mse: 0.3713
# Epoch 35/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3723 - mse: 0.3723
# Epoch 36/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 37/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3710 - mse: 0.3710
# Epoch 38/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3699 - mse: 0.3699
# Epoch 39/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3700 - mse: 0.3700
# Epoch 40/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 41/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3729 - mse: 0.3729
# Epoch 42/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 43/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3709 - mse: 0.3709
# Epoch 44/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3711 - mse: 0.3711
# Epoch 45/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3706 - mse: 0.3706
# Epoch 46/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3694 - mse: 0.3694
# Epoch 47/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3755 - mse: 0.3755
# Epoch 48/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3715 - mse: 0.3715
# Epoch 49/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 50/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3696 - mse: 0.3696
# Epoch 51/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 52/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3721 - mse: 0.3721
# Epoch 53/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3712 - mse: 0.3712
# Epoch 54/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3776 - mse: 0.3776
# Epoch 55/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3716 - mse: 0.3716
# Epoch 56/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3699 - mse: 0.3699
# Epoch 57/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3708 - mse: 0.3708
# Epoch 58/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3695 - mse: 0.3695
# Epoch 59/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3714 - mse: 0.3714
# Epoch 60/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3723 - mse: 0.3723
# Epoch 61/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3739 - mse: 0.3739
# Epoch 62/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3716 - mse: 0.3716
# Epoch 63/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3722 - mse: 0.3722
# Epoch 64/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3694 - mse: 0.3694
# Epoch 65/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3718 - mse: 0.3718
# Epoch 66/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3698 - mse: 0.3698
# Epoch 67/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 68/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3711 - mse: 0.3711
# Epoch 69/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3703 - mse: 0.3703
# Epoch 70/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3694 - mse: 0.3694
# Epoch 71/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3700 - mse: 0.3700
# Epoch 72/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 73/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3694 - mse: 0.3694
# Epoch 74/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3697 - mse: 0.3697
# Epoch 75/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3711 - mse: 0.3711
# Epoch 76/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3741 - mse: 0.3741
# Epoch 77/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3722 - mse: 0.3722
# Epoch 78/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3704 - mse: 0.3704
# Epoch 79/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3700 - mse: 0.3700
# Epoch 80/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3715 - mse: 0.3715
# Epoch 81/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 82/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3695 - mse: 0.3695
# Epoch 83/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3719 - mse: 0.3719
# Epoch 84/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3703 - mse: 0.3703
# Epoch 85/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3704 - mse: 0.3704
# Epoch 86/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3710 - mse: 0.3710
# Epoch 87/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3709 - mse: 0.3709
# Epoch 88/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3737 - mse: 0.3737
# Epoch 89/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3712 - mse: 0.3712
# Epoch 90/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 91/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3729 - mse: 0.3729
# Epoch 92/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3711 - mse: 0.3711
# Epoch 93/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3707 - mse: 0.3707
# Epoch 94/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3700 - mse: 0.3700
# Epoch 95/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3700 - mse: 0.3700
# Epoch 96/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3718 - mse: 0.3718
# Epoch 97/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3704 - mse: 0.3704
# Epoch 98/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3718 - mse: 0.3718
# Epoch 99/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3727 - mse: 0.3727
# Epoch 100/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3721 - mse: 0.3721
# Epoch 101/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3707 - mse: 0.3707
# Epoch 102/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3704 - mse: 0.3704
# Epoch 103/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 104/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3710 - mse: 0.3710
# Epoch 105/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3709 - mse: 0.3709
# Epoch 106/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 107/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3706 - mse: 0.3706
# Epoch 108/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3703 - mse: 0.3703
# Epoch 109/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3706 - mse: 0.3706
# Epoch 110/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3697 - mse: 0.3697
# Epoch 111/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3724 - mse: 0.3724
# Epoch 112/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3696 - mse: 0.3696
# Epoch 113/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3730 - mse: 0.3730
# Epoch 114/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 115/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3720 - mse: 0.3720
# Epoch 116/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3726 - mse: 0.3726
# Epoch 117/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3692 - mse: 0.3692
# Epoch 118/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 119/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3710 - mse: 0.3710
# Epoch 120/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3699 - mse: 0.3699
# Epoch 121/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3745 - mse: 0.3745
# Epoch 122/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3724 - mse: 0.3724
# Epoch 123/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3714 - mse: 0.3714
# Epoch 124/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 125/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3708 - mse: 0.3708
# Epoch 126/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3696 - mse: 0.3696
# Epoch 127/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3693 - mse: 0.3693
# Epoch 128/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3707 - mse: 0.3707
# Epoch 129/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3697 - mse: 0.3697
# Epoch 130/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3717 - mse: 0.3717
# Epoch 131/150
# 264/264 [==============================] - 0s 1ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 132/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3770 - mse: 0.3770
# Epoch 133/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3701 - mse: 0.3701
# Epoch 134/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3720 - mse: 0.3720
# Epoch 135/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 136/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3709 - mse: 0.3709
# Epoch 137/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3690 - mse: 0.3690
# Epoch 138/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3706 - mse: 0.3706
# Epoch 139/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3697 - mse: 0.3697
# Epoch 140/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3700 - mse: 0.3700
# Epoch 141/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3714 - mse: 0.3714
# Epoch 142/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3696 - mse: 0.3696
# Epoch 143/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3696 - mse: 0.3696
# Epoch 144/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 145/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3696 - mse: 0.3696
# Epoch 146/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3705 - mse: 0.3705
# Epoch 147/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3734 - mse: 0.3734
# Epoch 148/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3709 - mse: 0.3709
# Epoch 149/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3702 - mse: 0.3702
# Epoch 150/150
# 264/264 [==============================] - 0s 2ms/step - loss: 0.3701 - mse: 0.3701

# %%
scores = model.evaluate(x_test, y_test)
print((model.metrics_names[1]))
# Out:
# 141/141 [==============================] - 0s 1ms/step - loss: 0.4102 - mse: 0.4102
# mse
